# %%
# !pip3 install --upgrade torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu117
# !pip3 install roboflow
# !pip3 install --upgrade ultralytics

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
ROBOFLOW_API_KEY = user_secrets.get_secret("ROBOFLOW_API")

from roboflow import Roboflow
rf = Roboflow(api_key=ROBOFLOW_API_KEY)
project = rf.workspace("zhihang").project("fruits-and-vegetables-knetf-9dd0s")
dataset = project.version(1).download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !cat /kaggle/working/Fruits-and-Vegetables-1/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 22
# names: ['apple', 'banana', 'bell_pepper', 'cabbage', 'carrot', 'chilli_pepper', 'corn', 'cucumber', 'eggplant', 'garlic', 'grape', 'kiwi', 'lemon', 'lettuce', 'mango', 'onion', 'orange', 'pineapple', 'potato', 'sweetpotato', 'tomato', 'watermelon']
#
# roboflow:
#   workspace: zhihang
#   project: fruits-and-vegetables-knetf-9dd0s
#   version: 1
#   license: Public Domain
#   url: https://universe.roboflow.com/zhihang/fruits-and-vegetables-knetf-9dd0s/dataset/1

# %%
# !yolo task=detect mode=train epochs=50 data=/kaggle/working/Fruits-and-Vegetables-1/data.yaml model=yolo11m.pt patience=30
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.100 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: task=detect, mode=train, model=yolo11m.pt, data=/kaggle/working/Fruits-and-Vegetables-1/data.yaml, epochs=50, time=None, patience=30, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 3.95MB/s]
# Overriding model.yaml nc=80 with nc=22
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1427986  ultralytics.nn.modules.head.Detect           [22, [256, 512, 512]]
# YOLO11m summary: 231 layers, 20,069,970 parameters, 20,069,954 gradients, 68.3 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /kaggle/working/Fruits-and-Vegetables-1/train/labels.cache... 12
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.5 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /kaggle/working/Fruits-and-Vegetables-1/valid/labels.cache... 363
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000385, momentum=0.9) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      8.28G      1.132      2.893        1.5         61        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.347      0.526      0.407      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      10.3G      1.131      1.972       1.41         47        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.468      0.412      0.384      0.235
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      10.3G      1.173      1.937      1.464         61        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.341      0.455       0.35      0.197
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      10.4G      1.194      1.882      1.501         57        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.435      0.424      0.412      0.249
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      10.5G      1.161      1.722      1.461         61        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804       0.43      0.507      0.472      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      10.5G      1.138      1.664      1.451         67        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.584      0.487      0.513      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      10.6G      1.117      1.621      1.436         55        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.578       0.54      0.558      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      10.6G      1.095      1.499      1.422         97        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.555      0.591      0.614      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      10.6G      1.087      1.467      1.401         68        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.543      0.616      0.594      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      10.6G      1.077      1.399       1.41         76        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.558      0.643      0.636      0.425
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      10.6G      1.064      1.376      1.382         34        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.538      0.675      0.637      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      10.6G      1.042      1.338      1.374         50        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.618      0.637      0.673      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      10.6G      1.015       1.23       1.36         60        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.591      0.674      0.678      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      10.6G      1.005      1.217      1.349         64        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.583      0.693      0.702      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      10.6G     0.9759      1.193      1.342         39        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804       0.66      0.662      0.703      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      10.6G     0.9755      1.158      1.329         79        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.646      0.663      0.698      0.485
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      10.6G     0.9687      1.127      1.317         68        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.671      0.714       0.73      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      10.6G     0.9507      1.073      1.313         76        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804        0.7      0.617      0.714      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      10.6G     0.9675      1.048      1.319         55        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.662      0.664      0.714      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      10.6G     0.9499      1.029      1.299         64        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.655      0.722      0.736      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      10.6G      0.932      1.019      1.292         64        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.674      0.663      0.725      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      10.6G      0.929     0.9728      1.299         60        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.675      0.713      0.734      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      10.6G     0.8925     0.9277      1.272         63        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.629      0.726       0.74      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      10.6G     0.9139     0.9336      1.285        107        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.713      0.725      0.773      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      10.6G     0.8967     0.9325      1.263         69        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.726      0.726      0.782      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      10.6G     0.8594     0.8719      1.236         51        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.678      0.763      0.784      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      10.6G     0.8606     0.8595      1.234         55        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.712      0.705      0.777      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      10.6G     0.8626     0.8269      1.251         54        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804       0.66      0.742      0.757      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      10.6G       0.86     0.8064      1.239         77        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.745      0.694      0.778      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      10.6G      0.841     0.7691      1.223         66        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.689      0.743      0.768      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      10.6G     0.8108     0.7363      1.206         61        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.764      0.701      0.773      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      10.6G     0.8084      0.744      1.208         60        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.699      0.768      0.798      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      10.6G      0.793     0.7085      1.203         66        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.737      0.721      0.764      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      10.6G      0.796     0.6979      1.208         65        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.701      0.738       0.78      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      10.6G     0.7709      0.675      1.174         71        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.737      0.716      0.783      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      10.6G     0.7656     0.6599      1.177         60        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.738      0.747      0.803      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      10.6G     0.7491     0.6608      1.176         60        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.747       0.73       0.79      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      10.6G     0.7501     0.6363      1.165         67        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.766        0.7      0.796      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      10.6G     0.7346     0.6142      1.151         73        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.732      0.733       0.79      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      10.6G     0.7127     0.5911      1.149         48        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.745      0.733      0.792      0.579
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      10.6G     0.6363     0.4845      1.108         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.738      0.727      0.782      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      10.6G     0.6076     0.4438      1.076         28        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.759      0.719      0.802      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      10.6G     0.5854     0.3845      1.059         71        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.756      0.743      0.808      0.589
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      10.6G       0.58     0.3932      1.059         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.766       0.72      0.797      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      10.6G     0.5575     0.3671       1.04         45        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.733      0.765      0.806      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      10.6G     0.5387       0.35      1.024         34        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.751      0.734      0.806      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      10.6G     0.5392     0.3457      1.028         21        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.755      0.723      0.801      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      10.6G     0.5287     0.3359      1.014         33        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.746      0.759      0.798      0.589
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      10.6G     0.5193     0.3253      1.015         27        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.778      0.705      0.792      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      10.6G      0.498     0.3119      1.007         34        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.761      0.727      0.794      0.588
#
# 50 epochs completed in 0.912 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 40.5MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 40.5MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.100 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11m summary (fused): 125 layers, 20,046,994 parameters, 0 gradients, 67.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        363        804      0.751      0.733      0.806      0.598
#                  apple         17         22      0.876      0.818      0.936      0.776
#                 banana         11         14      0.732          1      0.913      0.759
#            bell_pepper         37        114      0.795      0.719      0.846      0.669
#                cabbage         10         16      0.739      0.709       0.86      0.602
#                 carrot         20         52      0.637      0.885      0.823      0.508
#          chilli_pepper         31         86      0.602      0.581      0.606      0.402
#                   corn         26         53      0.836      0.887      0.924      0.629
#               cucumber         20         51      0.776      0.817      0.859      0.609
#               eggplant         16         33      0.796       0.97       0.94      0.673
#                 garlic          6         19      0.753      0.804      0.894      0.547
#                  grape         16         24      0.854      0.792      0.949      0.639
#                   kiwi          9         35      0.736      0.637      0.696      0.484
#                  lemon         15         32      0.693      0.781      0.743      0.505
#                lettuce         17         20      0.958        0.8      0.874      0.769
#                  mango         20         49      0.764      0.776      0.883      0.652
#                  onion         11         24      0.269      0.261      0.328      0.213
#                 orange          9         21      0.816      0.667       0.81      0.706
#              pineapple         12         21          1      0.656      0.962      0.726
#                 potato         12         34      0.768      0.676      0.776      0.667
#            sweetpotato         13         42      0.753      0.548      0.709       0.47
#                 tomato         16         25      0.486       0.48      0.465      0.358
#             watermelon         16         17      0.881      0.873      0.939      0.788
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# Speed: 0.1ms preprocess, 10.3ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to runs/detect/train2
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
#!yolo task=detect mode=train resume model=/kaggle/working/runs/detect/train/weights/best.pt data=/kaggle/working/Fruits-and-Vegetables-1/data.yaml epochs=100

# %%
# !ls /kaggle/working/runs/detect/train
# Out:
# args.yaml					  train_batch1.jpg
# confusion_matrix_normalized.png			  train_batch2.jpg
# confusion_matrix.png				  train_batch3200.jpg
# events.out.tfevents.1743510771.df09ac55cac8.85.0  train_batch3201.jpg
# F1_curve.png					  train_batch3202.jpg
# labels_correlogram.jpg				  val_batch0_labels.jpg
# labels.jpg					  val_batch0_pred.jpg
# P_curve.png					  val_batch1_labels.jpg
# PR_curve.png					  val_batch1_pred.jpg
# R_curve.png					  val_batch2_labels.jpg
# results.csv					  val_batch2_pred.jpg
# results.png					  weights
# train_batch0.jpg
